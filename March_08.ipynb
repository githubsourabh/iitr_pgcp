# %%
array1 = [1,2,3]
array2 = [4,5,6]
array3 =[1,5,9]
array4= (array1[0]^array2[0]^array3[0],array1[1]^array2[1]^array3[1],array1[2]^array2[2]^array3[2])
len(arr)
print (array4)
# Out:
# (4, 2, 12)

# %%
def generateAllCombinationsOfSize_n_withPossibleDigitsUpto_m(n,m):
    arr = []
    for i in range (n):
        for j in range (m):
            tupl = ()

# %%
#write a function to generate all possible permutations of your name
